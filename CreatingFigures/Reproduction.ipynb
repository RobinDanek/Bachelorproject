# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
g = globals()

# %%
df = pd.read_csv(f"D:\Daten mit Änderungen\Physik\Bachelorarbeit\Generated_Data\Original\\a0.05_Consensus.csv", header = None)
data1 = df.to_numpy()
df = pd.read_csv(f"D:\Daten mit Änderungen\Physik\Bachelorarbeit\Generated_Data\Original\\a3.0_Polarization.csv", header = None)
data2 = df.to_numpy()
df = pd.read_csv(f"D:\Daten mit Änderungen\Physik\Bachelorarbeit\Generated_Data\Original\\a3.0_Ideology.csv", header = None)
data3 = df.to_numpy()

# %%
fig, ax = plt.subplots(3,3, figsize=(12,11), constrained_layout=True)
for i in range(3):
    ax[i][0].hist(g[f"data{i+1}"][3], bins=120, density=True)
    ax[i][1].hist(g[f"data{i+1}"][4], bins=120, density=True)
    ax[i][0].set_xlabel("Opinion 1")
    ax[i][1].set_xlabel("Opinion 2")
    #g[f"im{i+1}"] = ax[i][2].scatter(g[f"data{i+1}"][3], g[f"data{i+1}"][4], c=g[f"data{i+1}"][0], cmap='hot', marker = '2', alpha=1.0)
    g[f"im{i+1}"] = ax[i][2].scatter(g[f"data{i+1}"][3], g[f"data{i+1}"][4], marker = '2', alpha=0.1)
    #plt.colorbar(g[f"im{i+1}"], ax=ax[i, 2])
    ax[i][2].set_xlabel("Opinion 1")
    ax[i][2].set_ylabel("Opinion 2")
    # ax[i][0].grid()
    # ax[i][1].grid()
    ax[i][2].grid()
ax[0][0].set_xlim(-0.005,0.005)
ax[0][1].set_xlim(-0.005,0.005)
ax[0][2].set_xlim(-0.005,0.005)
ax[0][2].set_ylim(-0.005,0.005)
ax[0][2].set_xlim(-10,10)
ax[0][2].set_ylim(-10,10)
ax[1][2].set_xlim(-10,10)
ax[1][2].set_ylim(-10,10)
ax[2][2].set_xlim(-10,10)
ax[2][2].set_ylim(-10,10)
ax[0][1].set_title("Consensus, $\\alpha=0.05$, $\cos(\delta)=0$")
ax[1][1].set_title("Polarization, $\\alpha=3.0$, $\cos(\delta)=0$")
ax[2][1].set_title("Ideology, $\\alpha=3.0$, $\cos(\delta)=\\frac{1}{\sqrt{2}}$")
ax[1][1].set_xlim(-30,30)
ax[1][0].set_xlim(-30,30)
ax[2][1].set_xlim(-30,30)
ax[2][0].set_xlim(-30,30)
plt.savefig("D:/Daten mit Änderungen/Physik/Bachelorarbeit/Code/Creating_Figures/Reproduction.png", dpi=300)

# %%
mean = 0
for i in range (len(data2[3])):
    mean += np.abs(data2[3][i])
mean /= len(data2[3])
print(mean)
# Out:
# 2.045797016436485

# %%
plt.figure(figsize=(5,4))
sc = plt.scatter(g[f"data2"][3], g[f"data2"][4], c=g[f"data2"][0], cmap='hot', marker = '2', alpha=1.0)
plt.xlabel("Opinion 1")
plt.ylabel("Opinion 2")
plt.grid()
cb = plt.colorbar(sc)
cb.set_label("activity")
plt.savefig("D:/Daten mit Änderungen/Physik/Bachelorarbeit/Code/Creating_Figures/Polarization_Activity.png", dpi=300)
