# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

g = globals()

# %%
alphas = [1.0, 3.0]
cosds = [0.0, 0.5]

for i in range(2):
    for j in range(2):
        g[f"data{2*i+j+1}"] = np.loadtxt(f"D:\Daten mit Änderungen\Physik\Bachelorarbeit\Generated_Data\Original\means_a{alphas[i]}_cosd{cosds[j]}_means.csv", delimiter=',')
        g[f"mean{2*i+j+1}_mean"] = np.mean(g[f"data{2*i+j+1}"], axis=1)

# %%
figure, ax = plt.subplots(len(alphas), len(cosds), sharex = True, sharey=True, figsize=(6,6))

step = np.arange(10, 991, 10)

print(len(step), len(data1[:,0]))

for i in range(2):
    for j in range(2):
        for k in range(2500):
            ax[i][j].scatter(step, g[f"data{2*i+j+1}"][:,k], marker='2', color='red', alpha=0.2, s=1.0)
        ax[i][j].plot(step, g[f"mean{2*i+j+1}_mean"], color = 'lime')
        ax[i][j].set_title(f"$\\alpha=${alphas[i]}, $\\cos(\delta)$={cosds[j]}")
    ax[i][0].set_ylabel("Distance")
ax[0][0].set_xlabel("iteration")
ax[0][1].set_xlabel("iteration")

plt.tight_layout()
plt.savefig("D:/Daten mit Änderungen/Physik/Bachelorarbeit/Figures/Stability.png", dpi=300)
# Out:
# 99 99
